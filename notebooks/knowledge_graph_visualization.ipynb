# %% [markdown]
# # Purpose
# This file will test and visualize the knowledge graph class. Need to validate the knowledge graph is implemented thw way it should be.

# %%
#Include the files that need to be included by the package 
import sys
import os 
sys.path.append(os.path.abspath('..')) #needs to identify global package
import matplotlib.pyplot as plt 
from src.knowledge_graph import KnowledgeGraph
import networkx as nx

# %%
#Initializing the knowledge graph
kg = KnowledgeGraph()


# ── ROOT ──────────────────────────────────────────────────────────────────────
kg.add_node("Machine Learning")

# ══════════════════════════════════════════════════════════════════════════════
# FOUNDATIONAL KNOWLEDGE
# ══════════════════════════════════════════════════════════════════════════════
kg.add_node("Foundational Knowledge")
kg.add_edge("Machine Learning", "Foundational Knowledge")

# ── Mathematics for ML ────────────────────────────────────────────────────────
kg.add_node("Mathematics for ML")
kg.add_edge("Foundational Knowledge", "Mathematics for ML")

kg.add_node("Linear Algebra")
kg.add_edge("Mathematics for ML", "Linear Algebra")
kg.add_node("Maths & Matrix Operations")
kg.add_edge("Linear Algebra", "Maths & Matrix Operations")
kg.add_node("Scalars, Vectors, Tensors")
kg.add_edge("Linear Algebra", "Scalars, Vectors, Tensors")
kg.add_node("Singular Value Decomposition (SVD)")
kg.add_edge("Linear Algebra", "Singular Value Decomposition (SVD)")
kg.add_node("Determinants, Inverse of Matrix")
kg.add_edge("Linear Algebra", "Determinants, Inverse of Matrix")
kg.add_node("Eigenvalues, Vectors, Diagonalisation")
kg.add_edge("Linear Algebra", "Eigenvalues, Vectors, Diagonalisation")

kg.add_node("Calculus")
kg.add_edge("Mathematics for ML", "Calculus")
kg.add_edge("Linear Algebra", "Calculus")                          # prereq
kg.add_node("Derivatives, Partial Derivatives")
kg.add_edge("Calculus", "Derivatives, Partial Derivatives")
kg.add_node("Chain Rule of Derivatives")
kg.add_edge("Calculus", "Chain Rule of Derivatives")
kg.add_node("Gradient, Jacobian, Hessian")
kg.add_edge("Calculus", "Gradient, Jacobian, Hessian")

kg.add_node("Probability & Statistics")
kg.add_edge("Mathematics for ML", "Probability & Statistics")
kg.add_edge("Calculus", "Probability & Statistics")                # prereq
kg.add_node("Covariance, Correlation")
kg.add_edge("Probability & Statistics", "Covariance, Correlation")
kg.add_node("Basics of Probability")
kg.add_edge("Probability & Statistics", "Basics of Probability")
kg.add_node("Expectation, Variance")
kg.add_edge("Probability & Statistics", "Expectation, Variance")
kg.add_node("Bayes Theorem")
kg.add_edge("Probability & Statistics", "Bayes Theorem")
kg.add_node("Random Variables, PDFs")
kg.add_edge("Probability & Statistics", "Random Variables, PDFs")
kg.add_node("Types of Distributions")
kg.add_edge("Probability & Statistics", "Types of Distributions")

kg.add_node("Discrete Mathematics")
kg.add_edge("Mathematics for ML", "Discrete Mathematics")
kg.add_edge("Probability & Statistics", "Discrete Mathematics")   # prereq

# ── Programming Fundamentals ──────────────────────────────────────────────────
kg.add_node("Programming Fundamentals")
kg.add_edge("Foundational Knowledge", "Programming Fundamentals")

kg.add_node("Python Basics - Core Functions")
kg.add_edge("Programming Fundamentals", "Python Basics - Core Functions")
kg.add_node("Data Structures and OOPs")
kg.add_edge("Programming Fundamentals", "Data Structures and OOPs")
kg.add_edge("Python Basics - Core Functions", "Data Structures and OOPs")  # prereq

kg.add_node("Essential Libraries")
kg.add_edge("Programming Fundamentals", "Essential Libraries")
kg.add_edge("Data Structures and OOPs", "Essential Libraries")    # prereq
kg.add_node("SciPy")
kg.add_edge("Essential Libraries", "SciPy")
kg.add_node("NumPy")
kg.add_edge("Essential Libraries", "NumPy")
kg.add_node("Pandas")
kg.add_edge("Essential Libraries", "Pandas")
kg.add_node("Matplotlib")
kg.add_edge("Essential Libraries", "Matplotlib")
kg.add_node("Seaborn")
kg.add_edge("Essential Libraries", "Seaborn")

# ══════════════════════════════════════════════════════════════════════════════
# DATA COLLECTION & SOURCES
# ══════════════════════════════════════════════════════════════════════════════
kg.add_node("Data Collection & Sources")
kg.add_edge("Machine Learning", "Data Collection & Sources")
kg.add_edge("Programming Fundamentals", "Data Collection & Sources")   # prereq
kg.add_edge("Essential Libraries", "Data Collection & Sources")        # prereq

kg.add_node("CSV, JSON, Excel Files")
kg.add_edge("Data Collection & Sources", "CSV, JSON, Excel Files")
kg.add_node("APIs (using Requests, Tweepy etc.)")
kg.add_edge("Data Collection & Sources", "APIs (using Requests, Tweepy etc.)")
kg.add_node("Web Scraping (BeautifulSoup, Scrapy)")
kg.add_edge("Data Collection & Sources", "Web Scraping (BeautifulSoup, Scrapy)")
kg.add_node("Databases (SQL, No-SQL)")
kg.add_edge("Data Collection & Sources", "Databases (SQL, No-SQL)")

# ══════════════════════════════════════════════════════════════════════════════
# DATA CLEANING & PREPROCESSING
# ══════════════════════════════════════════════════════════════════════════════
kg.add_node("Data Cleaning & Preprocessing")
kg.add_edge("Machine Learning", "Data Cleaning & Preprocessing")
kg.add_edge("Data Collection & Sources", "Data Cleaning & Preprocessing")  # prereq
kg.add_edge("Mathematics for ML", "Data Cleaning & Preprocessing")         # prereq
kg.add_edge("Programming Fundamentals", "Data Cleaning & Preprocessing")   # prereq

kg.add_node("Data Cleaning")
kg.add_edge("Data Cleaning & Preprocessing", "Data Cleaning")
kg.add_node("Feature Engineering")
kg.add_edge("Data Cleaning & Preprocessing", "Feature Engineering")
kg.add_edge("Data Cleaning", "Feature Engineering")                        # prereq
kg.add_node("Feature Scaling & Normalisation")
kg.add_edge("Data Cleaning & Preprocessing", "Feature Scaling & Normalisation")
kg.add_edge("Feature Engineering", "Feature Scaling & Normalisation")      # prereq
kg.add_node("Dimensionality Reduction")
kg.add_edge("Data Cleaning & Preprocessing", "Dimensionality Reduction")
kg.add_edge("Linear Algebra", "Dimensionality Reduction")                  # prereq
kg.add_node("Feature Selection")
kg.add_edge("Data Cleaning & Preprocessing", "Feature Selection")
kg.add_edge("Feature Engineering", "Feature Selection")                    # prereq

# ══════════════════════════════════════════════════════════════════════════════
# CLASSICAL MACHINE LEARNING
# ══════════════════════════════════════════════════════════════════════════════
kg.add_node("Classical Machine Learning")
kg.add_edge("Machine Learning", "Classical Machine Learning")
kg.add_edge("Data Cleaning & Preprocessing", "Classical Machine Learning") # prereq
kg.add_edge("Mathematics for ML", "Classical Machine Learning")            # prereq
kg.add_edge("Programming Fundamentals", "Classical Machine Learning")      # prereq

# ── Supervised Learning ───────────────────────────────────────────────────────
kg.add_node("Supervised Learning")
kg.add_edge("Classical Machine Learning", "Supervised Learning")

kg.add_node("Regression")
kg.add_edge("Supervised Learning", "Regression")
kg.add_node("Linear & Polynomial Regression")
kg.add_edge("Regression", "Linear & Polynomial Regression")
kg.add_node("Ridge, Lasso, Elasticnet Regularization")
kg.add_edge("Regression", "Ridge, Lasso, Elasticnet Regularization")
kg.add_edge("Linear & Polynomial Regression", "Ridge, Lasso, Elasticnet Regularization")  # prereq

kg.add_node("Classification")
kg.add_edge("Supervised Learning", "Classification")
kg.add_edge("Regression", "Classification")                                # prereq
kg.add_node("K-Nearest Neighbors (KNN)")
kg.add_edge("Classification", "K-Nearest Neighbors (KNN)")
kg.add_node("Gradient Boosting Machines (GBM)")
kg.add_edge("Classification", "Gradient Boosting Machines (GBM)")
kg.add_node("Support Vector Machines (SVM)")
kg.add_edge("Classification", "Support Vector Machines (SVM)")
kg.add_node("Decision Trees, Random Forests")
kg.add_edge("Classification", "Decision Trees, Random Forests")
kg.add_node("Logistic Regression")
kg.add_edge("Classification", "Logistic Regression")
kg.add_edge("Linear & Polynomial Regression", "Logistic Regression")      # prereq

# ── Unsupervised Learning ─────────────────────────────────────────────────────
kg.add_node("Unsupervised Learning")
kg.add_edge("Classical Machine Learning", "Unsupervised Learning")
kg.add_edge("Supervised Learning", "Unsupervised Learning")                # prereq

kg.add_node("Clustering Algos")
kg.add_edge("Unsupervised Learning", "Clustering Algos")
kg.add_edge("Unsupervised Learning", "Dimensionality Reduction")           # already added node

# ── Model Evaluation & Metrics ────────────────────────────────────────────────
kg.add_node("Model Evaluation & Metrics")
kg.add_edge("Classical Machine Learning", "Model Evaluation & Metrics")
kg.add_edge("Supervised Learning", "Model Evaluation & Metrics")           # prereq
kg.add_edge("Unsupervised Learning", "Model Evaluation & Metrics")         # prereq
kg.add_edge("Probability & Statistics", "Model Evaluation & Metrics")      # prereq

kg.add_node("Accuracy, Precision, Recall")
kg.add_edge("Model Evaluation & Metrics", "Accuracy, Precision, Recall")
kg.add_node("F1-Score, ROC-AUC, Log Loss")
kg.add_edge("Model Evaluation & Metrics", "F1-Score, ROC-AUC, Log Loss")
kg.add_edge("Accuracy, Precision, Recall", "F1-Score, ROC-AUC, Log Loss") # prereq
kg.add_node("K-Fold Cross Validation, LOOCV")
kg.add_edge("Model Evaluation & Metrics", "K-Fold Cross Validation, LOOCV")
kg.add_node("Confusion Matrix")
kg.add_edge("Model Evaluation & Metrics", "Confusion Matrix")

# ══════════════════════════════════════════════════════════════════════════════
# NEURAL NETWORKS
# ══════════════════════════════════════════════════════════════════════════════
kg.add_node("Neural Networks")
kg.add_edge("Machine Learning", "Neural Networks")
kg.add_edge("Classical Machine Learning", "Neural Networks")               # prereq
kg.add_edge("Linear Algebra", "Neural Networks")                           # prereq
kg.add_edge("Calculus", "Neural Networks")                                 # prereq
kg.add_edge("Model Evaluation & Metrics", "Neural Networks")               # prereq

# ── Deep Learning Foundations ─────────────────────────────────────────────────
kg.add_node("Deep Learning Foundations")
kg.add_edge("Neural Networks", "Deep Learning Foundations")

kg.add_node("Perceptron, Multi Layer Perceptrons")
kg.add_edge("Deep Learning Foundations", "Perceptron, Multi Layer Perceptrons")
kg.add_node("Forward Propagation, Backpropagation")
kg.add_edge("Deep Learning Foundations", "Forward Propagation, Backpropagation")
kg.add_edge("Calculus", "Forward Propagation, Backpropagation")            # prereq
kg.add_edge("Perceptron, Multi Layer Perceptrons", "Forward Propagation, Backpropagation")  # prereq
kg.add_node("Activation Functions")
kg.add_edge("Deep Learning Foundations", "Activation Functions")
kg.add_edge("Perceptron, Multi Layer Perceptrons", "Activation Functions") # prereq
kg.add_node("Loss Functions")
kg.add_edge("Deep Learning Foundations", "Loss Functions")
kg.add_edge("Probability & Statistics", "Loss Functions")                  # prereq

# ── Deep Learning Architecture ────────────────────────────────────────────────
kg.add_node("Deep Learning Architecture")
kg.add_edge("Neural Networks", "Deep Learning Architecture")
kg.add_edge("Deep Learning Foundations", "Deep Learning Architecture")     # prereq

kg.add_node("Convolution Neural Networks")
kg.add_edge("Deep Learning Architecture", "Convolution Neural Networks")
kg.add_edge("Linear Algebra", "Convolution Neural Networks")               # prereq
kg.add_node("Convolution, Pooling, Padding, Strides")
kg.add_edge("Convolution Neural Networks", "Convolution, Pooling, Padding, Strides")
kg.add_node("Image Classification - LeNet, AlexNet, VGG etc.")
kg.add_edge("Convolution Neural Networks", "Image Classification - LeNet, AlexNet, VGG etc.")
kg.add_edge("Convolution, Pooling, Padding, Strides", "Image Classification - LeNet, AlexNet, VGG etc.")  # prereq

kg.add_node("Recurrent Neural Networks")
kg.add_edge("Deep Learning Architecture", "Recurrent Neural Networks")
kg.add_edge("Convolution Neural Networks", "Recurrent Neural Networks")    # prereq
kg.add_node("RNN")
kg.add_edge("Recurrent Neural Networks", "RNN")
kg.add_node("GRU")
kg.add_edge("Recurrent Neural Networks", "GRU")
kg.add_edge("RNN", "GRU")                                                  # prereq
kg.add_node("LSTM")
kg.add_edge("Recurrent Neural Networks", "LSTM")
kg.add_edge("GRU", "LSTM")                                                 # prereq

kg.add_node("Attention Mechanisms")
kg.add_edge("Deep Learning Architecture", "Attention Mechanisms")
kg.add_edge("Recurrent Neural Networks", "Attention Mechanisms")           # prereq
kg.add_node("Self-Attention")
kg.add_edge("Attention Mechanisms", "Self-Attention")
kg.add_node("Transformers (BERT, GPT)")
kg.add_edge("Attention Mechanisms", "Transformers (BERT, GPT)")
kg.add_edge("Self-Attention", "Transformers (BERT, GPT)")                  # prereq
kg.add_node("Multi-Head Attention")
kg.add_edge("Attention Mechanisms", "Multi-Head Attention")
kg.add_edge("Self-Attention", "Multi-Head Attention")                      # prereq

kg.add_node("Autoencoders")
kg.add_edge("Deep Learning Architecture", "Autoencoders")
kg.add_edge("Deep Learning Foundations", "Autoencoders")                   # prereq

kg.add_node("Generative Adversarial Networks (GANs)")
kg.add_edge("Deep Learning Architecture", "Generative Adversarial Networks (GANs)")
kg.add_edge("Autoencoders", "Generative Adversarial Networks (GANs)")      # prereq

# ══════════════════════════════════════════════════════════════════════════════
# ADVANCED CONCEPTS IN ML
# ══════════════════════════════════════════════════════════════════════════════
kg.add_node("Advanced Concepts in ML")
kg.add_edge("Machine Learning", "Advanced Concepts in ML")
kg.add_edge("Neural Networks", "Advanced Concepts in ML")                  # prereq
kg.add_edge("Deep Learning Architecture", "Advanced Concepts in ML")       # prereq
kg.add_edge("Model Evaluation & Metrics", "Advanced Concepts in ML")       # prereq

# ── Natural Language Processing ───────────────────────────────────────────────
kg.add_node("Natural Language Processing (NLP)")
kg.add_edge("Advanced Concepts in ML", "Natural Language Processing (NLP)")
kg.add_edge("Classical Machine Learning", "Natural Language Processing (NLP)")      # prereq
kg.add_edge("Attention Mechanisms", "Natural Language Processing (NLP)")            # prereq
kg.add_edge("Probability & Statistics", "Natural Language Processing (NLP)")        # prereq

kg.add_node("Tokenisation")
kg.add_edge("Natural Language Processing (NLP)", "Tokenisation")
kg.add_node("Stemming")
kg.add_edge("Natural Language Processing (NLP)", "Stemming")
kg.add_edge("Tokenisation", "Stemming")                                             # prereq
kg.add_node("Lemmatisation")
kg.add_edge("Natural Language Processing (NLP)", "Lemmatisation")
kg.add_edge("Tokenisation", "Lemmatisation")                                        # prereq
kg.add_node("Embeddings")
kg.add_edge("Natural Language Processing (NLP)", "Embeddings")
kg.add_edge("Linear Algebra", "Embeddings")                                         # prereq
kg.add_node("Attention Models")
kg.add_edge("Natural Language Processing (NLP)", "Attention Models")
kg.add_edge("Embeddings", "Attention Models")                                       # prereq
kg.add_edge("Transformers (BERT, GPT)", "Attention Models")                         # prereq
kg.add_node("Sentiment Analysis, Named Entity Recognition (NER)")
kg.add_edge("Natural Language Processing (NLP)", "Sentiment Analysis, Named Entity Recognition (NER)")
kg.add_edge("Embeddings", "Sentiment Analysis, Named Entity Recognition (NER)")     # prereq

# ── Reinforcement Learning ────────────────────────────────────────────────────
kg.add_node("Reinforcement Learning")
kg.add_edge("Advanced Concepts in ML", "Reinforcement Learning")
kg.add_edge("Classical Machine Learning", "Reinforcement Learning")        # prereq
kg.add_edge("Neural Networks", "Reinforcement Learning")                   # prereq
kg.add_edge("Probability & Statistics", "Reinforcement Learning")          # prereq

kg.add_node("Q-Learning")
kg.add_edge("Reinforcement Learning", "Q-Learning")
kg.add_node("Deep Q-Networks")
kg.add_edge("Reinforcement Learning", "Deep Q-Networks")
kg.add_edge("Q-Learning", "Deep Q-Networks")                               # prereq
kg.add_node("Policy Gradients")
kg.add_edge("Reinforcement Learning", "Policy Gradients")
kg.add_edge("Deep Q-Networks", "Policy Gradients")                         # prereq
kg.add_node("Actor-Critic Methods")
kg.add_edge("Reinforcement Learning", "Actor-Critic Methods")
kg.add_edge("Policy Gradients", "Actor-Critic Methods")                    # prereq

# ── Explainable AI ────────────────────────────────────────────────────────────
kg.add_node("Explainable AI (XAI)")
kg.add_edge("Advanced Concepts in ML", "Explainable AI (XAI)")
kg.add_edge("Classical Machine Learning", "Explainable AI (XAI)")          # prereq
kg.add_edge("Neural Networks", "Explainable AI (XAI)")                     # prereq
kg.add_edge("Deep Learning Architecture", "Explainable AI (XAI)")          # prereq

# ── Continue Learning ─────────────────────────────────────────────────────────
kg.add_node("Continue Learning")
kg.add_edge("Advanced Concepts in ML", "Continue Learning")
kg.add_edge("Explainable AI (XAI)", "Continue Learning")                   # prereq
kg.add_edge("Reinforcement Learning", "Continue Learning")                  # prereq
kg.add_edge("Natural Language Processing (NLP)", "Continue Learning")       # prereq
# Out:
# True

# %%
G = nx.DiGraph(kg.edges)
plt.figure(figsize=(30,30))
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, arrows=True)
plt.title("Knowledge Graph")
plt.plot()
# Out:
# []

# %%
#tests for the best path 
print(kg.edges)
print(kg.get_learning_path("machine learning", "Convolution neural networks", []))
# Out:
# {'machine learning': ['foundational knowledge', 'data collection & sources', 'data cleaning & preprocessing', 'classical machine learning', 'neural networks', 'advanced concepts in ml'], 'foundational knowledge': ['mathematics for ml', 'programming fundamentals'], 'mathematics for ml': ['linear algebra', 'calculus', 'probability & statistics', 'discrete mathematics', 'data cleaning & preprocessing', 'classical machine learning'], 'linear algebra': ['maths & matrix operations', 'scalars, vectors, tensors', 'singular value decomposition (svd)', 'determinants, inverse of matrix', 'eigenvalues, vectors, diagonalisation', 'calculus', 'dimensionality reduction', 'neural networks', 'convolution neural networks', 'embeddings'], 'maths & matrix operations': [], 'scalars, vectors, tensors': [], 'singular value decomposition (svd)': [], 'determinants, inverse of matrix': [], 'eigenvalues, vectors, diagonalisation': [], 'calculus': ['derivatives, partial derivatives', 'chain rule of derivatives'
# ...
